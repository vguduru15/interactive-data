# %% [markdown]
# # Data

# %% [markdown]
# ### Interactive Data

# %% [markdown]
# **Bold**

# %% [markdown]
# _Varshitha_

# %% [markdown]
# * **Interactive Visualizations**: Learn about how to build the active visuals providing the capability to satisfy the user’s demand in data and reveal new insights.
#
# * **Design Best Practices**: Understand how to make visualizations easy to comprehend and beautiful in order to make data readable and easy to understand for the user.
#
# * _Exploratory Data Analysis (EDA)_: EDA should be used in the form of visualization methods to provide you with the first ideas and hunches about the overall data structure, possible outliers, and correlations before having formal tests conducted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variable assignment
a="Varshitha"
print(a)
# Out:
# Varshitha

# %%
#for loop
for i in ["Varshitha","is", "a","person","of","Indian","descent"]:
    print(i)
# Out:
# Varshitha
# is
# a
# person
# of
# Indian
# descent

# %%
# a function with a print statement

def add(x,y):
    c=x+y
    print(c)

# %%
add(34,66)
# Out:
# 100

# %%
# a function with a return statement

def add_return(x,y):
    c=x+y
    return c

# %%
add_return(9,7)
# Out:
# 16
